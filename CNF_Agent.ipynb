# %% [markdown]
# # CNF Agent
#
# This agent's knowledgebase is a conjunction of disjunctions of literals.  The literals take the form M(i, j).  THis means there is a mine at (i, j).  Its negation is that (i. j) is safe.
#
# The agent has a .kb attribute that represents its knowledgebase.  It is a list of clauses that are assumed to be AND'ed together.  Each clause is a list of literals that are assumed to be OR'ed together.
#
# This agent will go through the following functions to solve the board:
#
#     (1) Discover single literal clauses to deduce mine and safe locations
#         + If a single literal is M(i, j), then (i, j) is a mine
#         + If a single literal is -M(i, j), then (i, j) is not a mine
#
#
#     (2) Query the knowledgebase for -M(i, j).
#          If this query is unsat, then (i, j) is a mine
#
#     (3)  Query the knowledgebase for M(i, j).
#          If this query is unsat, then (i, j) is safe
#
#     (4)  Uncover random covered, unflagged cell

# %% [markdown]
# ## Imports

# %%
import numpy as np
import numpy as np
import itertools
from importlib import reload

import board as board 
import cnf_agent

import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %% [markdown]
# ## Spawn board and agent

# %%
brd = board.Board(15, 45)
agent = cnf_agent.CNF_Agent(brd)
# Out:
# <img src="data:image/png;base64,..." width="565.5555705376618">

# %%
agent.solve()
# Out:
# 0.9333333333333333

# %% [markdown]
# ## Solve in two ways:
#
# + agent.solve(interactive=False, log=False, delay=0)
#     + This will solve the entire board.  Cannot view the knowledgebase between steps
# + agent.solve_one_iteration(log=False)
#     + This will have the agent step forward once in solving.   The knowledgebase can be viewed between steps with agent.kb

# %%
agent.solve(log=False)
# Out:
# 1.0

# %%
# Returns how many times the agent resorted to randomly clicking some covered cell 
agent.random_clicks
# Out:
# 9

# %%
len(agent.kb.clauses)
# Out:
# 580

# %% [markdown]
# ## Testing

# %%
brd = board.Board(15, 30)
agent = cnf_agent.CNF_Agent(brd)
# Out:
# <img src="data:image/png;base64,..." width="566.2499915622176">

# %%
agent.solve()
# Out:
# 1.0

# %%
# Returns how many times the agent resorted to randomly clicking some covered cell 
agent.random_clicks
# Out:
# 0
