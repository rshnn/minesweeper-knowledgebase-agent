# %% [markdown]
# # Bonus
#
# A new board object was created called JerkBoard.  The JerkBoard takes in a parameter called the `fog_probability`.  This is the chance that the board will not notify the agent of the hint value when uncovering safe cells.
#
# A modified CNF Agent was designed to cope with this jerk board.

# %%
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload

# %%
# %matplotlib notebook

# %%
import jerk_board
import cnf_bonus_agent

import matplotlib.pyplot as plt

# %%
jbrd = jerk_board.JerkBoard(15, 45, 0.2)
agent = cnf_bonus_agent.CNF_Bonus_Agent(jbrd)
# Out:
# <img src="data:image/png;base64,..." width="565.5555705376618">

# %%
agent.solve()
# Out:
# 0.9555555555555556

# %%
jbrd.score, agent.random_clicks

# %% [markdown]
# ## Lets make some plots

# %%
import analysis

# %%
metrics = analysis.generate_score_vs_prob_list(15, 45, 15, 2)
# Out:
# <img src="data:image/png;base64,..." width="565.5555705376618">
# <img src="data:image/png;base64,..." width="565.5555705376618">
# <img src="data:image/png;base64,..." width="565.5555705376618">
# <img src="data:image/png;base64,..." width="565.5555705376618">
# <img src="data:image/png;base64,..." width="565.5555705376618">
# <img src="data:image/png;base64,..." width="565.5555705376618">
# <img src="data:image/png;base64,..." width="565.5555705376618">
# <img src="data:image/png;base64,..." width="565.5555705376618">
# <img src="data:image/png;base64,..." width="565.5555705376618">
# <img src="data:image/png;base64,..." width="565.5555705376618">
# <img src="data:image/png;base64,..." width="565.5555705376618">
# <img src="data:image/png;base64,..." width="565.5555705376618">
# <img src="data:image/png;base64,..." width="565.5555705376618">
# <img src="data:image/png;base64,..." width="565.5555705376618">
# <img src="data:image/png;base64,..." width="565.5555705376618">
# ...

# %%
metrics
# Out:
# [(0.0, 1.0, 1.5),
#  (0.07142857142857142, 0.9777777777777777, 1.0),
#  (0.14285714285714285, 0.9222222222222223, 10.5),
#  (0.21428571428571427, 0.8333333333333333, 27.5),
#  (0.2857142857142857, 0.8, 44.0),
#  (0.3571428571428571, 0.7, 50.5),
#  (0.42857142857142855, 0.7, 70.5),
#  (0.5, 0.5444444444444444, 76.5),
#  (0.5714285714285714, 0.4666666666666667, 85.5),
#  (0.6428571428571428, 0.3666666666666667, 109.0),
#  (0.7142857142857142, 0.3666666666666667, 125.5),
#  (0.7857142857142857, 0.26666666666666666, 153.0),
#  (0.8571428571428571, 0.1111111111111111, 173.0),
#  (0.9285714285714285, 0.044444444444444446, 192.5),
#  (1.0, 0.0, 224.0)]

# %%
import seaborn as sns

# %%
probs = [i[0] for i in metrics]
scores = [i[1] for i in metrics]
rands = [i[2] for i in metrics]

fig = plt.figure(figsize=(10, 8))

ax = sns.lineplot(probs, scores)

ax.set(xlabel='fog probability', ylabel='average score', title='Average score versus fog probability for 15x15 board with 45 mines')
# Out:
# /home/rshn/miniconda3/envs/ds/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """
# <img src="data:image/png;base64,..." width="998.8889153504084">
# [Text(0, 0.5, 'average score'),
#  Text(0.5, 0, 'fog probability'),
#  Text(0.5, 1.0, 'Average score versus fog probability for 15x15 board with 45 mines')]

# %%
fig = plt.figure(figsize=(10, 8))

ax = sns.lineplot(probs, rands)

ax.set(xlabel='fog probability', ylabel='average random clicks', title='Average random clicks versus fog probability for 15x15 board with 45 mines')
# Out:
# /home/rshn/miniconda3/envs/ds/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <img src="data:image/png;base64,..." width="998.8889153504084">
# [Text(0, 0.5, 'average random clicks'),
#  Text(0.5, 0, 'fog probability'),
#  Text(0.5, 1.0, 'Average random clicks versus fog probability for 15x15 board with 45 mines')]

# %%
probs = [i[0] for i in basic_score]
scores = [i[1] for i in basic_score]
rands = [i[2] for i in basic_score]

fig = plt.figure(figsize=(10, 8))

ax = sns.lineplot(probs, scores)

ax.set(xlabel='fog probability', ylabel='average number of random clicks', title='Comparing average random clicks between agents on {}x{} board'.format(dim, dim))

# %% [markdown]
# ## Play by play

# %%
jbrd = jerk_board.JerkBoard(15, 45, 0.2)
agent = cnf_bonus_agent.CNF_Bonus_Agent(jbrd)
# Out:
# <img src="data:image/png;base64,..." width="565.5555705376618">

# %%
agent.solve_one_iteration(log=True)
# Out:
# 	Randomly selected (6, 14) to uncover.
# Excavated (6, 14) for hint of 4
# Added -M(6, 14, idx:105) to knowledgebase.
# Generating clauses at (6, 14, 105). 4 mines, 0 neighbors

# %%
jbrd.check_gameover_conditions()
# Out:
# True

# %%
jbrd.score, agent.random_clicks
# Out:
# (0.9555555555555556, 0)

# %% [markdown]
# # Harder board

# %%
jbrd = jerk_board.JerkBoard(15, 45, 0.5)
agent = cnf_bonus_agent.CNF_Bonus_Agent(jbrd)
# Out:
# <img src="data:image/png;base64,..." width="565.5555705376618">

# %%
agent.solve_one_iteration()
# Out:
# 0.35555555555555557

# %%
jbrd.check_gameover_conditions()
jbrd.score
# Out:
# 0.35555555555555557
