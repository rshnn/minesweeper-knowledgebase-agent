# %% [markdown]
# # Basic Agent
#
#
# The basic agent solves the minesweeper game using local search across the maze.  After uncovering one cell, it will iterate through all the cells on the board to determine if it can make any judgements about mine positions and safe cells.  If it cannot make any judgements given the state of the board, it will randomly chose a covered cell to uncover.

# %%
import board as board 
import basic_agent as basic_agent

# %%
import matplotlib.pyplot as plt
from importlib import reload

# %matplotlib notebook

# %%
# reload module for debugging 
reload(board)
reload(basic_agent)
# Out:
# <module 'basic_agent' from 'C:\\Users\\roshan.r.patel\\Development\\cs\\asst2-520\\basic_agent.py'>

# %%
brd = board.Board(15, 30)
agent = basic_agent.BasicAgent(brd)
# Out:
# <img src="data:image/png;base64,..." width="565.5555705376618">

# %%
# In this function, the first cell uncovered is (0,0).  
agent.solve(interactive=False, log=True)
# Out:
# 	Randomly selected (8, 0) to uncover.
# 	Randomly selected (3, 14) to uncover.
# 	Randomly selected (13, 14) to uncover.
# Cell (14, 14) deemed safe using (13, 14).
# Cell (12, 13) deemed safe using (13, 14).
# Cell (12, 14) deemed safe using (13, 14).
# Cell (13, 13) deemed safe using (13, 14).
# Cell (14, 13) deemed safe using (13, 14).
# Excavated (12, 13)
# Excavated (12, 14)
# Excavated (13, 13)
# Excavated (14, 13)
# Excavated (14, 14)
# Cell (12, 12) deemed safe using (13, 13).
# Cell (13, 12) deemed safe using (13, 13).
# Cell (14, 12) deemed safe using (13, 13).
# Cell (13, 12) deemed safe using (14, 13).
# Cell (14, 12) deemed safe using (14, 13).
# Excavated (12, 12)
# Excavated (13, 12)
# Excavated (14, 12)
# 	Randomly selected (0, 3) to uncover.
# 	Randomly selected (5, 6) to uncover.
# Cell (6, 7) deemed safe using (5, 6).
# Cell (6, 6) deemed safe using (5, 6).
# Cell (5, 7) deemed safe using (5, 6).
# Cell (4, 7) deemed safe using (5, 6).
# ...

# %%
agent.cells
