# %%
import matplotlib.pyplot as plt
from importlib import reload

# %matplotlib notebook

# %%
import board

# %%
# Reloads module for debuggin 
reload(board)
# Out:
# <module 'board' from 'C:\\Users\\roshan.r.patel\\Development\\cs\\asst2-520\\board.py'>

# %%
b = board.Board(5, 5)
# Out:
# <img src="data:image/png;base64,..." width="233">

# %% [markdown]
# ### Run this to check if game is over.
# Currently, this isnt checked automatically.

# %%
if b.check_gameover_conditions():
    print(b.score)
# Out:
# 4

# %% [markdown]
# # User interface for playing game

# %% [markdown]
# ## Selecting a cell (left click)

# %%
b.user_select(1, 0)
# b.user_select(2, 1)
# b.user_select(3, 2)
# b.user_select(4, 3)
# b.user_select(1, 4)
# b.user_select(2, 4)
# b.user_select(3, 4)
# b.user_select(4, 4)
# b.user_select(3, 3)
# b.user_select(4, 2)
# Out:
# 1

# %% [markdown]
# ## Toggling flag (right click)

# %%
b.user_flag(0,0)

# %% [markdown]
# ## Reveal contents of board
# For debugging, not for agent use.
# Warning -- Purges flag state.

# %%
b1 = board.Board(15, 10)
# Out:
# <img src="data:image/png;base64,..." width="566.2222222222222">

# %%
b1._reveal_board()
